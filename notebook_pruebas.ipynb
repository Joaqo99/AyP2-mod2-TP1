# %%
import materiales

# %%
materiales.read_materials_table()
# Out:
#     Id.           Material  Densidad  Módulo de Young  Factor de pérdidas  \
# 0     1              Acero      7700     1.950000e+11              0.0001
# 1     2           Aluminio      2700     7.100000e+10              0.0010
# 2     3             Bronce      8500     9.500000e+10              0.0100
# 3     4              Cobre      8915     1.270000e+11              0.0100
# 4     5      Contrachapado       600     8.300000e+09              0.0500
# 5     6             Hierro      7700     1.950000e+11              0.0001
# 6     7           Hormigón      2400     3.000000e+10              0.0500
# 7     8  Hormigón ladrillo       900     4.800000e+09              0.0500
# 8     9           Ladrillo      2100     2.500000e+10              0.0100
# 9    10             Madera       650     1.200000e+10              0.0100
# 10   11           Neopreno      1200     1.000000e+08              0.1000
# 11   12              Plomo     11300     1.700000e+10              0.0005
# ...

# %%
#materiales.add_material({"Name": "Prueba", "Den": 2888, "YM":2e11, "LF":0.0001, "PM":0.12})

# %%
materiales.get_material_properties("Acero")
# Out:
#    Id. Material  Densidad  Módulo de Young  Factor de pérdidas  Módulo Poisson
# 0    1    Acero      7700     1.950000e+11              0.0001             0.3
